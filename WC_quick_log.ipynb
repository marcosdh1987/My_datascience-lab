# %%
import pandas as pd
import numpy as np

#csv_path = r'D:\Google Drive\Deep_Learning\Jupiter_Notebooks\ds\Laborales\G2\Exportados Pluspetrol Pad G2.csv'
csv_path = r'D:\OneDrive\OneDrive - WFT\Compartido\Trainings\TPS-FM-RE\Day-2\MP_LC_G2\Copy of Logger2_20200625_122700.csv'

data1 = pd.read_csv(csv_path,encoding='utf-8')

ds = data1.copy()

ds.describe()
# Out:
#                WLR  MLR [%]       XL [-]  Flow Rate       Tp [C]   Well#  \
# count  7840.000000   7840.0  7840.000000     7840.0  7840.000000  7840.0
# mean     55.312795      0.0     0.745904        0.0    54.213610     3.0
# std       4.900427      0.0     0.050877        0.0     0.978183     0.0
# min      11.920000      0.0     0.280000        0.0    47.100000     3.0
# 25%      56.030000      0.0     0.750000        0.0    53.700000     3.0
# 50%      56.310000      0.0     0.750000        0.0    54.200000     3.0
# 75%      56.550000      0.0     0.760000        0.0    54.700000     3.0
# max      57.990000      0.0     0.820000        0.0    56.200000     3.0
#
#             Status  4-20 In [counts]  Freq In [Hz]     PC1 [nA]     PC2 [nA]  \
# count  7840.000000       7840.000000        7840.0  7840.000000  7840.000000
# mean      3.957653          0.771939           0.0   360.031381     8.014189
# std       0.409409          0.422034           0.0    17.860911     4.559949
# ...

# %%
ds.columns
# Out:
# Index(['Time Stamp', 'WLR', 'MLR [%]', 'XL [-]', 'Flow Rate', 'Tp [C]',
#        'Well#', 'Status', '4-20 In [counts]', 'Freq In [Hz]', 'PC1 [nA]',
#        'PC2 [nA]', 'PC3 [nA]', 'PC4 [nA]', 'PC5 [nA]', 'Tb [C]'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#x = ds
x = ds.query('WLR > 50 ')

plt.figure(figsize=(19,8))
sns.kdeplot(x['WLR'], shade=True, label='WLR')
#sns.kdeplot(ds['SEP_Ctrl_OIL_Factor'], shade=True, label='SEP_Ctrl')
plt.title("Water Liquid Rate")
# Out:
# Text(0.5, 1.0, 'Water Liquid Rate')

# %%
import seaborn as sns
import pandas as pd
import earthpy as et

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

import matplotlib.pyplot as plt

fig, ax = plt.subplots(3,figsize=(22,15),sharex=True)
ds.plot(y='WLR',color='blue',ax=ax[0])
ds.plot(y='XL [-]',color='gray',ax=ax[1])
ds.plot(y='Tp [C]',color='orange',ax=ax[2])
ax[0].set(title="WLR chart")
ax[1].set(title="XL chart")
ax[2].set(title="Temp chart")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import earthpy as et

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Use white grid plot background from seaborn
sns.set(font_scale=1.5, style="whitegrid")

import matplotlib.pyplot as plt

fig, ax = plt.subplots(5,figsize=(22,15),sharex=True)
ds.plot(y='PC1 [nA]',color='blue',ax=ax[0])
ds.plot(y='PC2 [nA]',color='gray',ax=ax[1])
ds.plot(y='PC3 [nA]',color='orange',ax=ax[2])
ds.plot(y='PC4 [nA]',color='red',ax=ax[3])
ds.plot(y='PC5 [nA]',color='green',ax=ax[4])
plt.show()

# %%
sns.pairplot(ds[['WLR', 'PC1 [nA]','PC2 [nA]','PC3 [nA]','PC4 [nA]','PC5 [nA]']], diag_kind="kde")
