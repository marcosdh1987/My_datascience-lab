# %%
import scrapy

# Create the spider class
class YourSpider( scrapy.Spider ):
  name = "your_spider"
  # start_requests method
  def start_requests( self ):
    urls = ["https://www.datacamp.com","https://scrapy.org"]
    for url in urls:
      yield url
  # parse method
  def parse( self, response ):
    pass

# %%
# Create the spider class
class YourSpider( scrapy.Spider ):
  name = "your_spider"
  # start_requests method
  def start_requests( self ):
    yield scrapy.Request( url = "https://www.datacamp.com", callback = self.parse)
  # parse method
  def parse( self, response ):
    pass

# %%
# Import the scrapy library
import scrapy

# Create the Spider class
class DCspider( scrapy.Spider ):
  name = 'dcspider'
  # start_requests method
  def start_requests( self ):
    yield scrapy.Request( url = url_short, callback = self.parse )
  # parse method
  def parse( self, response ):
    # Create an extracted list of course author names
    author_names = response.css( 'p.course-block__author-name::text' ).extract()
    # Here we will just return the list of Authors
    return author_names

# %%
# Import the scrapy library
import scrapy

url = "https://www.datacamp.com"

# Create the Spider class
class DCdescr( scrapy.Spider ):
  name = 'dcdescr'
  # start_requests method
  def start_requests( self ):
    yield scrapy.Request( url = url, callback = self.parse )
  
  # First parse method
  def parse( self, response ):
    links = response.css( 'div.course-block > a::attr(href)' ).extract()
    # Follow each of the extracted links
    for link in links:
      yield response.follow( url = link, callback = self.parse_descr )
      
  # Second parsing method
  def parse_descr( self , response ):
    # Extract course description
    course_descr = response.css( 'p.course__description::text' ).extract_first()
    # For now, just yield the course description
    yield course_descr


print(DCdescr)
# Out:
# <class '__main__.DCdescr'>

# %%
# Import scrapy
import scrapy

# Import the CrawlerProcess: for running the spider
from scrapy.crawler import CrawlerProcess

# Create the Spider class
class DC_Description_Spider(scrapy.Spider):
  name = "dc_chapter_spider"
  # start_requests method
  def start_requests(self):
    yield scrapy.Request(url = url_short,
                         callback = self.parse_front)
  # First parsing method
  def parse_front(self, response):
    course_blocks = response.css('div.course-block')
    course_links = course_blocks.xpath('./a/@href')
    links_to_follow = course_links.extract()
    for url in links_to_follow:
      yield response.follow(url = url,
                            callback = self.parse_pages)
  # Second parsing method
  def parse_pages(self, response):
    # Create a SelectorList of the course titles text
    crs_title = response.xpath('//h1[contains(@class,"title")]/text()')
    # Extract the text and strip it clean
    crs_title_ext = crs_title.extract_first().strip()
    # Create a SelectorList of course descriptions text
    crs_descr = response.css( 'p.course__description::text' )
    # Extract the text and strip it clean
    crs_descr_ext = crs_descr.extract_first().strip()
    # Fill in the dictionary
    dc_dict[crs_title_ext] = crs_descr_ext

# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# Run the Spider
process = CrawlerProcess()
process.crawl(DC_Description_Spider)
process.start()

print(dc_dict)
# Out:
# 2020-12-30 22:02:42 [scrapy.utils.log] INFO: Scrapy 2.4.0 started (bot: scrapybot)
# 2020-12-30 22:02:42 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.7.4 (default, Aug 13 2019, 15:17:50) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Darwin-20.2.0-x86_64-i386-64bit
# 2020-12-30 22:02:42 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-30 22:02:42 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-12-30 22:02:42 [scrapy.extensions.telnet] INFO: Telnet Password: 493e2eab8d347339
# 2020-12-30 22:02:42 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-30 22:02:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-30 22:02:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-30 22:02:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-30 22:02:42 [scrapy.core.engine] INFO: Spider opened
# 2020-12-30 22:02:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-30 22:02:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6032
# ---------------------------------------------------------------------------
# ReactorNotRestartable                     Traceback (most recent call last)
# <ipython-input-53-fd0982959990> in <module>
#      39 process = CrawlerProcess()
#      40 process.crawl(DC_Description_Spider)
# ---> 41 process.start()
#      42
#      43 print(dc_dict)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scrapy/crawler.py in start(self, stop_after_crawl)
#     325         tp.adjustPoolsize(maxthreads=self.settings.getint('REACTOR_THREADPOOL_MAXSIZE'))
#     326         reactor.addSystemEventTrigger('before', 'shutdown', self.stop)
# --> 327         reactor.run(installSignalHandlers=False)  # blocking call
#     328
#     329     def _graceful_stop_reactor(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twisted/internet/base.py in run(self, installSignalHandlers)
#    1280
#    1281     def run(self, installSignalHandlers=True):
# -> 1282         self.startRunning(installSignalHandlers=installSignalHandlers)
#    1283         self.mainLoop()
#    1284
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twisted/internet/base.py in startRunning(self, installSignalHandlers)
#    1260         """
#    1261         self._installSignalHandlers = installSignalHandlers
# -> 1262         ReactorBase.startRunning(self)
#    1263
#    1264
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twisted/internet/base.py in startRunning(self)
#     763             raise error.ReactorAlreadyRunning()
#     764         if self._startedBefore:
# --> 765             raise error.ReactorNotRestartable()
#     766         self._started = True
#     767         self._stopped = False
#
# ReactorNotRestartable:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from urllib.request import Request,urlopen
from bs4 import BeautifulSoup
# Out:
# 2020-12-30 22:43:36 [matplotlib.pyplot] DEBUG: Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"

#url = 'https://www.datamind.cl/'
req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})
#soup = BeautifulSoup(html, 'lxml')
soup = BeautifulSoup(html)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>Race results for the 2017 Intel Great Place to Run \ Urban Clash Games!</title>

# %%
# Print out the text
text = soup.get_text()
#print(soup.text)

# %%
all_links = soup.find_all("a")
for link in all_links:
    print(link.get("href"))
# Out:
# mailto:timing@hubertiming.com
# https://www.hubertiming.com/
# /results/2017GPTR
# /results/team/2017GPTR
# /results/team/2017GPTR10K
# /results/summary/2017GPTR10K
# None
# #tabs-1
# https://www.hubertiming.com/
# https://facebook.com/hubertiming/
# None

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
#print(rows[:10])

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td>577</td>, <td>443</td>, <td>
#
#                     LIBBY B MITCHELL
#
#                 </td>, <td>F</td>, <td>HILLSBORO</td>, <td>OR</td>, <td>1:41:18</td>, <td>16:20</td>, <td>1:42:10</td>, <td></td>]
# bs4.element.ResultSet

# %%
str_cells = str(row_td)
cleantext = BeautifulSoup(str_cells, "lxml").get_text()
print(cleantext)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 16:20, 1:42:10, ]

# %%
import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)
print(clean2)
type(clean2)
# Out:
# [577, 443,
#
#                     LIBBY B MITCHELL
#
#                 , F, HILLSBORO, OR, 1:41:18, 16:20, 1:42:10, ]
# str

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814, \r\n\r\n                    JARED WIL...
# 6  [2, 573, \r\n\r\n                    NATHAN A ...
# 7  [3, 687, \r\n\r\n                    FRANCISCO...
# 8  [4, 623, \r\n\r\n                    PAUL MORR...
# 9  [5, 569, \r\n\r\n                    DEREK G O...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#              0      1                                                  2  \
# 0           []   None                                               None
# 1  [Finishers:   577]                                               None
# 2       [Male:   414]                                               None
# 3     [Female:   163]                                               None
# 4           []   None                                               None
# 5           [1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           [2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           [3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           [4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
# 9           [5    569   \r\n\r\n                    DEREK G OSBORNE\r...
#
#       3           4     5       6      7       8  \
# 0  None        None  None    None   None    None
# 1  None        None  None    None   None    None
# 2  None        None  None    None   None    None
# 3  None        None  None    None   None    None
# 4  None        None  None    None   None    None
# 5     M      TIGARD    OR   36:21   5:51   36:24
# 6     M    PORTLAND    OR   36:42   5:55   36:45
# 7     M    PORTLAND    OR   37:44   6:05   37:48
# 8     M   BEAVERTON    OR   38:34   6:13   38:37
# 9     M   HILLSBORO    OR   39:21   6:20   39:24
#
#                                                    9
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0      1                                                  2     3  \
# 0           ]   None                                               None  None
# 1  Finishers:   577]                                               None  None
# 2       Male:   414]                                               None  None
# 3     Female:   163]                                               None  None
# 4           ]   None                                               None  None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...     M
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...     M
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...     M
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...     M
# 9           5    569   \r\n\r\n                    DEREK G OSBORNE\r...     M
#
#             4     5       6      7       8  \
# 0        None  None    None   None    None
# 1        None  None    None   None    None
# 2        None  None    None   None    None
# 3        None  None    None   None    None
# 4        None  None    None   None    None
# 5      TIGARD    OR   36:21   5:51   36:24
# 6    PORTLAND    OR   36:42   5:55   36:45
# 7    PORTLAND    OR   37:44   6:05   37:48
# 8   BEAVERTON    OR   38:34   6:13   38:37
# 9   HILLSBORO    OR   39:21   6:20   39:24
#
#                                                    9
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
col_labels = soup.find_all('th')

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Place, Bib, Name, Gender, City, State, Chip Time, Chip Pace, Gun Time, Team]']

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, State, Chip T...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#         0     1      2        3      4       5           6           7  \
# 0  [Place   Bib   Name   Gender   City   State   Chip Time   Chip Pace
#
#            8       9
# 0   Gun Time   Team]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#             0      1                                                  2  \
# 0      [Place    Bib                                               Name
# 0           ]   None                                               None
# 1  Finishers:   577]                                               None
# 2       Male:   414]                                               None
# 3     Female:   163]                                               None
# 4           ]   None                                               None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
#
#          3           4       5           6           7          8  \
# 0   Gender        City   State   Chip Time   Chip Pace   Gun Time
# 0     None        None    None        None        None       None
# 1     None        None    None        None        None       None
# 2     None        None    None        None        None       None
# 3     None        None    None        None        None       None
# 4     None        None    None        None        None       None
# 5        M      TIGARD      OR       36:21        5:51      36:24
# 6        M    PORTLAND      OR       36:42        5:55      36:45
# 7        M    PORTLAND      OR       37:44        6:05      37:48
# 8        M   BEAVERTON      OR       38:34        6:13      38:37
#
#                                                    9
# 0                                              Team]
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace  \
# 0      [Place    Bib   Name   Gender   City   State   Chip Time   Chip Pace
# 0           ]   None   None     None   None    None        None        None
# 1  Finishers:   577]   None     None   None    None        None        None
# 2       Male:   414]   None     None   None    None        None        None
# 3     Female:   163]   None     None   None    None        None        None
#
#     Gun Time   Team]
# 0   Gun Time   Team]
# 0       None    None
# 1       None    None
# 2       None    None
# 3       None    None

# %%
df6 = df5.dropna(axis=0, how='any')

# %%
df7 = df6.drop(df6.index[0])
df7.head()
# Out:
#   [Place   Bib                                               Name  Gender  \
# 5      1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6      2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7      3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8      4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9      5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  State  Chip Time  Chip Pace  Gun Time  \
# 5      TIGARD     OR      36:21       5:51     36:24
# 6    PORTLAND     OR      36:42       5:55     36:45
# 7    PORTLAND     OR      37:44       6:05     37:48
# 8   BEAVERTON     OR      38:34       6:13     38:37
# 9   HILLSBORO     OR      39:21       6:20     39:24
#
#                                                Team]
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Team]': 'Team'},inplace=True)
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  State  Chip Time  Chip Pace  Gun Time  \
# 5      TIGARD     OR      36:21       5:51     36:24
# 6    PORTLAND     OR      36:42       5:55     36:45
# 7    PORTLAND     OR      37:44       6:05     37:48
# 8   BEAVERTON     OR      38:34       6:13     38:37
# 9   HILLSBORO     OR      39:21       6:20     39:24
#
#                                                 Team
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
df7['Team'] = df7['Team'].str.strip(']')
df7.head()
# Out:
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  State  Chip Time  Chip Pace  Gun Time  \
# 5      TIGARD     OR      36:21       5:51     36:24
# 6    PORTLAND     OR      36:42       5:55     36:45
# 7    PORTLAND     OR      37:44       6:05     37:48
# 8   BEAVERTON     OR      38:34       6:13     38:37
# 9   HILLSBORO     OR      39:21       6:20     39:24
#
#                                                 Team
# 5
# 6   \n\r\n                            INTEL TEAM ...
# 7
# 8
# 9   \n\r\n                            INTEL TEAM ...

# %%
time_list = df7[' Chip Time'].tolist()

# You can use a for loop to convert 'Chip Time' to minutes

time_mins = []
for i in time_list:
    h, m, s = i.split(':')
    math = (int(h) * 3600 + int(m) * 60 + int(s))/60
    time_mins.append(math)
#print(time_mins)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-69a22b9f15a9> in <module>
#       5 time_mins = []
#       6 for i in time_list:
# ----> 7     h, m, s = i.split(':')
#       8     math = (int(h) * 3600 + int(m) * 60 + int(s))/60
#       9     time_mins.append(math)
#
# ValueError: not enough values to unpack (expected 3, got 2)
