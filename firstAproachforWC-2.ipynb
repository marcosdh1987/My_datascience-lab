# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r'D:\Google Drive\Deep_Learning\Jupiter_Notebooks\ds\test_wc.csv')

print(df.head())
print(np.shape(df))
# Out:
#           wc        xl        wwc          ch1         ch2          ch3  \
# 0  57.333530  0.650209  57.397984  4309.002441  107.420998  3405.154053
# 1  57.213390  0.647539  57.365562  4273.820801  101.667519  3345.853271
# 2  56.951706  0.643252  57.309704  5608.216309  231.073837  5053.055664
# 3  56.594246  0.636666  57.212299  5047.143555  159.406692  4263.820313
# 4  56.146931  0.629184  57.152458  5332.767090  187.370529  4628.125488
#
#           ch4        ch5
# 0  375.262665  22.256338
# 1  364.007172  20.624853
# 2  624.598816  61.946972
# 3  497.064301  36.399033
# 4  551.674927  43.798321
# (600, 8)

# %%
test1 = np.array(df)
print(df.head())

#selecting all rows of columns 3 to the end of the dataframe
xs = test1[:,3:]
#[:,0] all rows of column 1 named wc
ys = test1[:,0]

print(np.shape(xs))
print(np.shape(ys))

plt.scatter(test1[:,1],ys)
plt.show()
# Out:
#           wc        xl        wwc          ch1         ch2          ch3  \
# 0  57.333530  0.650209  57.397984  4309.002441  107.420998  3405.154053
# 1  57.213390  0.647539  57.365562  4273.820801  101.667519  3345.853271
# 2  56.951706  0.643252  57.309704  5608.216309  231.073837  5053.055664
# 3  56.594246  0.636666  57.212299  5047.143555  159.406692  4263.820313
# 4  56.146931  0.629184  57.152458  5332.767090  187.370529  4628.125488
#
#           ch4        ch5
# 0  375.262665  22.256338
# 1  364.007172  20.624853
# 2  624.598816  61.946972
# 3  497.064301  36.399033
# 4  551.674927  43.798321
# (600, 5)
# (600,)

# %%
x = df['ch1'].values
y = df['wc'].values

plt.scatter(x,y,color='blue')
plt.title("all data")
plt.show()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size= 0.5, random_state=42)

plt.scatter(X_train,y_train,color='blue')
plt.title("train sample")
plt.show()

plt.scatter(X_test,y_test,color='red')
plt.title("test sample")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
X_train = X_train.reshape(-1,1)

reg.fit(X_train, y_train)


prediction_space = np.linspace(min(x), max(x)).reshape(-1,1)

plt.scatter(X_train, y_train, color='blue')
plt.plot(prediction_space, reg.predict(prediction_space),
        color='black', linewidth=3)
plt.show()

# %%
y_pred = reg.predict(X_test.reshape(-1,1))

print(y_pred[1:2])
# Out:
# [61.38977849]
