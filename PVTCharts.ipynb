# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from numpy import genfromtxt


#data1 = genfromtxt(r'D:\Google Drive\Deep_Learning\Jupiter_Notebooks\ds\Laborales\G2\pvt_oil_sg.csv', delimiter=',')
#data2 = genfromtxt(r'D:\Google Drive\Deep_Learning\Jupiter_Notebooks\ds\Laborales\G2\pvt_oil_vs.csv', delimiter=',')

data1 = genfromtxt(r'D:\Weatherford\Flow Measurements\Pilotos de Prueba\PLUSPETROL - LC - G2\DATA_Files\Contrast_Calibration\pvt_models\pvt_oil_fvf_pvt4.csv', delimiter=',')
data2 = genfromtxt(r'D:\Weatherford\Flow Measurements\Pilotos de Prueba\PLUSPETROL - LC - G2\DATA_Files\Contrast_Calibration\pvt_models\pvt_oil_fvf_pvt5.csv', delimiter=',')
data3 = genfromtxt(r'D:\Weatherford\Flow Measurements\Pilotos de Prueba\PLUSPETROL - LC - G2\DATA_Files\Contrast_Calibration\pvt_models\pvt_oil_fvf_pvt6.csv', delimiter=',')

# %%
fig = plt.figure(figsize=(24,8))
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(70, 100, 1.5)
Y = np.arange(15, 75, 3)
X, Y = np.meshgrid(X, Y)

#R = np.sqrt(X**2 + Y**2)
#Z = np.sin(R)
Z1 = data1
Z2 = data2
Z3 = data3

# Plot the surface.
surf = ax.plot_surface(X, Y, Z1,cmap=cm.coolwarm, linewidth=0, antialiased=True)
surf = ax.plot_surface(X, Y, Z2,cmap=cm.coolwarm, linewidth=0, antialiased=True)
surf = ax.plot_surface(X, Y, Z3,cmap=cm.coolwarm, linewidth=0, antialiased=True)

# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf,shrink=0.5, aspect=5)

plt.show()
# Out:
# C:\Users\e196315\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   app.launch_new_instance()
# C:\Users\e196315\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Z contains NaN values. This may result in rendering artifacts.
# C:\Users\e196315\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Z contains NaN values. This may result in rendering artifacts.

# %%
#print(data1.shape)
#data1 = np.nan_to_num(data1)
